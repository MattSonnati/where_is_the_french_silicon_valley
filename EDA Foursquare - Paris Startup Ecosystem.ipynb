# %% [markdown]
# # Exploratory Data Analysis: Paris Startup Ecosystem

# %% [markdown]
# ## Introduction
#
# In this notebook, we conduct an Exploratory Data Analysis (EDA) of data about Paris Startup Ecosystem collected from the [Foursquare Places API](https://developer.foursquare.com). The idea is to better understand what the startup ecosystem in Paris in order to compare it with others cities.
#
# [Foursquare Places API](https://developer.foursquare.com) being a geo dataset, the analysis will mainly revolve around geographical analysis and Data Visualization on maps. Our area of investigation will focus on the category and quantity of organizations and companies that are related to startup eosystem.
#
# Our EDA approach follows the **Data Science Methodology CRISP-DM**. For more info about this approach, check this [Wikipedia page](https://en.wikipedia.org/wiki/Cross-industry_standard_process_for_data_mining)

# %% [markdown]
# ## Table of contents
# 1. [Data Collection](#item1)
# 2. [Data Visualization](#item2)
# 3. [Next steps](#item3)

# %% [markdown]
# First let's download all the libraries required for this notebook.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

from bs4 import BeautifulSoup # library for web parsing 

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
import urllib.request
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes 

import folium # map rendering library

from lxml.html import fromstring

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ## 1. Data Collection <a id='item1'></a>

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'xx' #  Foursquare ID
CLIENT_SECRET = 'xx' #  Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: xx
# CLIENT_SECRET:xx

# %% [markdown]
# #### Category selection

# %% [markdown]
# Foursquare has many categories. The full list can be accessed [here](https://developer.foursquare.com/docs/resources/categories). It goes from Restaurants to Stores and some of theses categories can widely impact any analysis just by their shear number of place. As a result, we decided to focus on selected categories that are more directely related to the life of startup, aka a Startup Ecosystem. We use the definition of a [Startup Ecosystem](https://en.wikipedia.org/wiki/Startup_ecosystem) according to Wikipedia.
# This list of category is definitely not exhaustive and could evolved based on the result of our analysis or any thoughtfull suggestions.

# %% [markdown]
# Obvisously the first category we selected was **Tech Startup** (4bf58dd8d48988d125941735) as this is the main focus of our analysis.
#
# Then we selected all the services that are required to the common operation of a startup:
# - **Coworking Space** (4bf58dd8d48988d174941735)
# - **Recruiting Agency** (52f2ab2ebcbc57f1066b8b57)
# - **Financial or Legal Service** (503287a291d4c4b30a586d65)
# - **Lawyer** (52f2ab2ebcbc57f1066b8b3f)
# - **Design Studio** (4bf58dd8d48988d1f4941735)
# - **Insurance Office** (58daa1558bbb0b01f18ec1f1)
# - **Business Service** (5453de49498eade8af355881)
# - **Business Center** (56aa371be4b08b9a8d573517)
# - **Advertising Agency** (52e81612bcbc57f1066b7a3d)
# - **Bank**	(4bf58dd8d48988d10a951735)
# - **Government Building**	(4bf58dd8d48988d126941735)
#
# We also selected the categories related to potential innovation partners of startup:
# - **College & University** (4d4b7105d754a06372d81259)
# - **Adult Education Center** (56aa371ce4b08b9a8d573570)
# - **Laboratory** (5744ccdfe4b0c0459246b4d6)
# - **Research Station** (58daa1558bbb0b01f18ec1b2)
#
# We also selected the categories related to potential industrial partners of startup:
# - **Industrial Estate** (56aa371be4b08b9a8d5734d7)
# - **Factory** (4eb1bea83b7b6f98df247e06)
#
# We also selected the categories related to potential cultural partners of startup:
# - **Library** (4bf58dd8d48988d12f941735)
# - **Science Museum** (4bf58dd8d48988d191941735)
# - **Art Museum** (4bf58dd8d48988d18f941735)
# - **History Museum** (4bf58dd8d48988d190941735)
# - **Planetarium** (4bf58dd8d48988d192941735)
#
#
#
# We then selected the category to various events that are required for startup to network and meet potential users or customers:
# - **Events** (4d4b7105d754a06373d81259)
# - **Trade Fair**	(5bae9231bedf3950379f89c3)
#
# The full list of categories was compiled in a csv file avaliable [here](https://raw.githubusercontent.com/MattSonnati/Data_Science_Coursera_Capstone/master/startup_ecosystem_category_list.csv)

# %%
startup_ecosystem_category_list = pd.read_csv('https://raw.githubusercontent.com/MattSonnati/where_is_the_french_silicon_valley/master/startup_ecosystem_category_list.csv').dropna()
startup_ecosystem_category_list
# Out:
#              4sq_category_name                    4sq_id color_code
# 0                 Tech Startup  4bf58dd8d48988d125941735    #32CD32
# 1              Coworking Space  4bf58dd8d48988d174941735    #ADFF2F
# 2             Insurance Office  58daa1558bbb0b01f18ec1f1    #FFD700
# 3            Recruiting Agency  52f2ab2ebcbc57f1066b8b57    #FFFFE0
# 4   Financial or Legal Service  503287a291d4c4b30a586d65    #FFE4B5
# 5                       Lawyer  52f2ab2ebcbc57f1066b8b3f    #FFFF00
# 6                   Laboratory  5744ccdfe4b0c0459246b4d6    #87CEFA
# 7         College & University  4d4b7105d754a06372d81259    #00BFFF
# 8       Adult Education Center  56aa371ce4b08b9a8d573570    #6495ED
# 9             Research Station  58daa1558bbb0b01f18ec1b2    #4169E1
# 10                     Library  4bf58dd8d48988d12f941735    #000080
# 11              Science Museum  4bf58dd8d48988d191941735    #EE82EE
# 12                  Art Museum  4bf58dd8d48988d18f941735    #8A2BE2
# 13              History Museum  4bf58dd8d48988d190941735    #9932CC
# 14                 Planetarium  4bf58dd8d48988d192941735    #800080
# 15                      Events  4d4b7105d754a06373d81259    #FF69B4
# 16             Business Center  56aa371be4b08b9a8d573517    #FF6347
# 17          Advertising Agency  52e81612bcbc57f1066b7a3d    #DC143C
# 18            Business Service  5453de49498eade8af355881    #FFA500
# 19               Design Studio  4bf58dd8d48988d1f4941735    #FFA07A
# 20                     Factory  4eb1bea83b7b6f98df247e06    #808080
# 21           Industrial Estate  56aa371be4b08b9a8d5734d7    #C0C0C0
# 22                        Bank  4bf58dd8d48988d10a951735    #008000
# 23                  Trade Fair  5bae9231bedf3950379f89c3    #AFEEEE
# 24         Government Building  4bf58dd8d48988d126941735    #F8F8FF

# %% [markdown]
# #### Area selection

# %% [markdown]
# In many instance, the geographical area referred to by poiting at a specific city is much wider than the administrative boundaries of said city. For example when people talk about startup from the "Bay area", SF or the Silicon Valley, in fact they refer to several cities from San Fransisco, Palo alto, Mountain view up to San Jose.
#
# For Paris, we thus decided to include every cities within 50 km from Paris.

# %% [markdown]
# We thus ask Foursquare API to find all the City (50aa9e094b90af0d42d5de0d) within 50000 meters from Paris, France

# %%
address_near = "Paris, France"
radius = 50000
category_id = "50aa9e094b90af0d42d5de0d"

# %%
# function that extracts the category name of the venue
def get_category_name(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venues.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
    # function that extracts the category of the venue
def get_category_id(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venues.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['id']
    
#create the GET request URL
LIMIT = 200

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&near={}&v={}&radius={}&limit={}&intent=browse&categoryId={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    address_near,  
    VERSION, 
    radius, 
    LIMIT,
    category_id)

# Send the GET request 
results = requests.get(url).json()

# Convert the JSON response into a dataframe
cities = results['response']['venues']
cities_list = json_normalize(cities) # flatten JSON

# filter columns
filtered_columns = ['name',
                    'id',
                    'location.postalCode',
                    'location.state',
                    'location.country',
                    'location.cc',
                    'location.lat', 
                    'location.lng',
                    'categories',]
cities_list =cities_list.loc[:, filtered_columns]

# filter the category for each row
cities_list['primary_category_name'] = cities_list.apply(get_category_name, axis=1)
cities_list['primary_category_id'] = cities_list.apply(get_category_id, axis=1)

# clean columns
cities_list.columns = [col.split(".")[-1] for col in cities_list.columns]

cities_list.head()
# Out:
#                    name                        id postalCode          state  \
# 0                 Paris  50dbd18d498eb594ef575b0a      75000  Île-de-France
# 1      Levallois-Perret  4ccc49e754f0b1f79d4515ca      92300  Île-de-France
# 2            Versailles  4b92dff4f964a5207e2334e3      78000  Île-de-France
# 3     Neuilly-sur-Seine  509f8996e4b05e06b5811a17      92200  Île-de-France
# 4  Boulogne-Billancourt  4c80bf1e74d7b60c080670d8      92100  Île-de-France
#
#   country  cc        lat       lng  \
# 0  France  FR  48.857006  2.351490
# 1  France  FR  48.893985  2.288295
# 2  France  FR  48.803472  2.126884
# 3  France  FR  48.884924  2.269471
# 4  France  FR  48.834141  2.242686
#
#                                           categories primary_category_name  \
# 0  [{'id': '50aa9e094b90af0d42d5de0d', 'name': 'C...                  City
# 1  [{'id': '50aa9e094b90af0d42d5de0d', 'name': 'C...                  City
# 2  [{'id': '50aa9e094b90af0d42d5de0d', 'name': 'C...                  City
# 3  [{'id': '50aa9e094b90af0d42d5de0d', 'name': 'C...                  City
# 4  [{'id': '50aa9e094b90af0d42d5de0d', 'name': 'C...                  City
#
#         primary_category_id
# 0  50aa9e094b90af0d42d5de0d
# 1  50aa9e094b90af0d42d5de0d
# 2  50aa9e094b90af0d42d5de0d
# 3  50aa9e094b90af0d42d5de0d
# 4  50aa9e094b90af0d42d5de0d

# %%
cities_list.shape
# Out:
# (50, 11)

# %%
# Save dataframe as csv file to localhost
cities_list.to_csv(r'paris_cities_list.csv')

# Save dataframe as csv file to Watson studio (need token)
# project.save_data(data=cities_list.to_csv(index=False),file_name='paris_cities_list.csv',overwrite=True)

# %% [markdown]
# #### List of Startup Ecosystem places in Paris area

# %% [markdown]
# For each city in the chosen area, we list all the places in our Category selection and within 5 km of said city.

# %%
def getCategoryVenues(name, latitude, longitude, radius, category_id):
    
    # create the API request URL
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}&intent=browse&categoryId={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    latitude, 
    longitude, 
    VERSION,
    radius, 
    LIMIT,
    category_id)

    # Send the GET request 
    results = requests.get(url).json()

    # Convert the JSON response into a dataframe
    category_venues = results['response']['venues']
    category_venues_list = json_normalize(category_venues) # flatten JSON

    # filter columns
    filtered_columns = ['name',
                            'id',
                            'location.postalCode',
                            'location.state',
                            'location.country',
                            'location.cc',
                            'location.lat', 
                            'location.lng',
                            'categories',]
    category_venues_list = category_venues_list.loc[:, filtered_columns]

    # filter the category for each row
    category_venues_list['primary_category_name'] = category_venues_list.apply(get_category_name, axis=1)
    category_venues_list['primary_category_id'] = category_venues_list.apply(get_category_id, axis=1)

    # clean columns
    category_venues_list.columns = [col.split(".")[-1] for col in category_venues_list.columns]

    return(category_venues_list)

# %%
radius = 5000
startup_ecosystem_place_list = pd.DataFrame(columns=['name','id','city','postalCode','state','country','cc','lat','lng','categoriesList','primary_category_name','primary_category_id'])

for category_name, category_id, color_code  in zip(startup_ecosystem_category_list['4sq_category_name'],
                                          startup_ecosystem_category_list['4sq_id'],
                                          startup_ecosystem_category_list['color_code']):
   
    for latitude, longitude, name  in zip(cities_list['lat'],
                                          cities_list['lng'],
                                          cities_list['name']):
        try:
            startup_ecosystem_place_list = pd.concat([startup_ecosystem_place_list, getCategoryVenues(name, latitude, longitude, radius, category_id)])
        except:
            pass

startup_ecosystem_place_list.drop_duplicates(subset=['id'], keep='first', inplace=True)
startup_ecosystem_place_list.head()
# Out:
# /Users/Matt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   if sys.path[0] == '':
# /Users/Matt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                                           categories categoriesList  cc city  \
# 0  [{'id': '4bf58dd8d48988d125941735', 'name': 'T...            NaN  FR  NaN
# 1  [{'id': '4bf58dd8d48988d125941735', 'name': 'T...            NaN  FR  NaN
# 2  [{'id': '4bf58dd8d48988d125941735', 'name': 'T...            NaN  FR  NaN
# 3  [{'id': '4bf58dd8d48988d125941735', 'name': 'T...            NaN  FR  NaN
# 4  [{'id': '4bf58dd8d48988d125941735', 'name': 'T...            NaN  FR  NaN
#
#   country                        id        lat       lng               name  \
# 0  France  58a16c5f51d19e06ce98f38d  48.868517  2.345687           Qonto HQ
# 1  France  4dac5df543a112819724533f  48.856391  2.293381  Salesforce France
# 2  France  59f711f53d4791157b9e7f62  48.880447  2.327044            Algolia
# 3  France  4fdee1f3e4b014c45c45905c  48.879049  2.332151             Criteo
# 4  France  59e9b4ec3abcaf334aa66d07  48.872823  2.350290        Spendesk HQ
#
#   postalCode       primary_category_id primary_category_name          state
# 0      75003  4bf58dd8d48988d125941735          Tech Startup  Île-de-France
# 1      75007  4bf58dd8d48988d125941735          Tech Startup  Île-de-France
# 2      75008  4bf58dd8d48988d125941735          Tech Startup  Île-de-France
# 3      75009  4bf58dd8d48988d125941735          Tech Startup  Île-de-France
# 4      75010  4bf58dd8d48988d125941735          Tech Startup  Île-de-France

# %%
startup_ecosystem_place_list.shape
# Out:
# (8277, 13)

# %%
# Save dataframe as csv file to localhost
startup_ecosystem_place_list.to_csv(r'paris_startup_ecosystem_place_list.csv')

# Save dataframe as csv file to Watson studio (need token)
# project.save_data(data=startup_ecosystem_place_list.to_csv(index=False),file_name='paris_startup_ecosystem_place_list.csv',overwrite=True)

# %% [markdown]
# ## 2. Data Visualization <a id='item2'></a>

# %% [markdown]
# First, let define a function to creat map from a list of Place based on their latitude and longitude coordinate.

# %%
def getMap(centerPlace, venues_list):

    # create a user agent
    geolocator = Nominatim(user_agent="fr_explorer")

    address = centerPlace
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude

    # create map using latitude and longitude values
    map_venues = folium.Map(location=[latitude, longitude], zoom_start=11)

    # add markers to map
    for lat, lng, name, postalCode  in zip(venues_list['lat'], 
                                                          venues_list['lng'], 
                                                          venues_list['name'], 
                                                          venues_list['postalCode']):
        label = '{} {}'.format(name, postalCode)
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            popup=label,
            color='blue',
            fill=True,
            fill_color='#3186cc',
            fill_opacity=0.7,
            parse_html=False).add_to(map_venues)  

    return(map_venues)

# %% [markdown]
# Map of cities within 50 km from Paris

# %%
 getMap('Paris, france', cities_list)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### To better understand Paris Startup Ecosystem, we can take a look at the number of place in each categories.

# %% [markdown]
# In order to better visualize these data, we can plot them as a horizontal bar plot.

# %%
count_per_category = startup_ecosystem_place_list.groupby('primary_category_name').count()
count_per_category.drop(['categories','categoriesList','state','postalCode','city'], axis=1, inplace=True)
count_per_category.sort_values(['id'], ascending=True, axis=0, inplace=True)
count_per_category
# Out:
#                                    cc  country    id   lat   lng  name  \
# primary_category_name
# Accessories Store                   1        1     1     1     1     1
# Memorial Site                       1        1     1     1     1     1
# Medical Supply Store                1        1     1     1     1     1
# Market                              1        1     1     1     1     1
# Lighting Store                      1        1     1     1     1     1
# Jewelry Store                       1        1     1     1     1     1
# Hotel                               1        1     1     1     1     1
# Health & Beauty Service             1        1     1     1     1     1
# Gym                                 1        1     1     1     1     1
# Music Festival                      1        1     1     1     1     1
# French Restaurant                   1        1     1     1     1     1
# Festival                            1        1     1     1     1     1
# Fair                                1        1     1     1     1     1
# Exhibit                             1        1     1     1     1     1
# Doner Restaurant                    1        1     1     1     1     1
# Currency Exchange                   1        1     1     1     1     1
# Cosmetics Shop                      1        1     1     1     1     1
# Convenience Store                   1        1     1     1     1     1
# Conference Room                     1        1     1     1     1     1
# Waste Facility                      1        1     1     1     1     1
# Music School                        1        1     1     1     1     1
# Newsstand                           1        1     1     1     1     1
# Outdoor Sculpture                   1        1     1     1     1     1
# Veterinarian                        1        1     1     1     1     1
# Trade Fair                          1        1     1     1     1     1
# Thrift / Vintage Store              1        1     1     1     1     1
# Theme Park                          1        1     1     1     1     1
# Tennis Stadium                      1        1     1     1     1     1
# Tailor Shop                         1        1     1     1     1     1
# TV Station                          1        1     1     1     1     1
# Street Fair                         1        1     1     1     1     1
# States & Municipalities             1        1     1     1     1     1
# Sporting Event                      1        1     1     1     1     1
# Smoke Shop                          1        1     1     1     1     1
# Shoe Store                          1        1     1     1     1     1
# Sculpture Garden                    1        1     1     1     1     1
# Radio Station                       1        1     1     1     1     1
# Professional & Other Places         1        1     1     1     1     1
# Performing Arts Venue               1        1     1     1     1     1
# Pedestrian Plaza                    1        1     1     1     1     1
# Parking                             1        1     1     1     1     1
# Paper / Office Supplies Store       1        1     1     1     1     1
# Comedy Club                         1        1     1     1     1     1
# College Technology Building         1        1     1     1     1     1
# Fountain                            1        1     1     1     1     1
# Wine Bar                            1        1     1     1     1     1
# Chocolate Shop                      1        1     1     1     1     1
# Child Care Service                  1        1     1     1     1     1
# Car Wash                            1        1     1     1     1     1
# Camera Store                        1        1     1     1     1     1
# Bookstore                           1        1     1     1     1     1
# Bike Shop                           1        1     1     1     1     1
# Basketball Stadium                  1        1     1     1     1     1
# Auto Workshop                       1        1     1     1     1     1
# Clothing Store                      1        1     1     1     1     1
# Athletics & Sports                  1        1     1     1     1     1
# Arts & Crafts Store                 1        1     1     1     1     1
# Art Studio                          1        1     1     1     1     1
# Auto Dealership                     1        1     1     1     1     1
# Transportation Service              2        2     2     2     2     2
# Tourist Information Center          2        2     2     2     2     2
# Castle                              2        2     2     2     2     2
# College Math Building               2        2     2     2     2     2
# Men's Store                         2        2     2     2     2     2
# Middle School                       2        2     2     2     2     2
# Event Service                       2        2     2     2     2     2
# Mobile Phone Shop                   2        2     2     2     2     2
# Museum                              2        2     2     2     2     2
# Doctor's Office                     2        2     2     2     2     2
# Café                                2        2     2     2     2     2
# Dance Studio                        2        2     2     2     2     2
# College Basketball Court            2        2     2     2     2     2
# Other Repair Shop                   2        2     2     2     2     2
# Parade                              2        2     2     2     2     2
# Bridge                              2        2     2     2     2     2
# Hospital                            2        2     2     2     2     2
# Boutique                            2        2     2     2     2     2
# Pet Service                         2        2     2     2     2     2
# Big Box Store                       2        2     2     2     2     2
# Concert Hall                        2        2     2     2     2     2
# College Soccer Field                2        2     2     2     2     2
# Automotive Shop                     2        2     2     2     2     2
# College Track                       2        2     2     2     2     2
# Cultural Center                     2        2     2     2     2     2
# Convention Center                   2        2     2     2     2     2
# Art Gallery                         3        3     3     3     3     3
# College History Building            3        3     3     3     3     3
# Electronics Store                   4        4     4     4     4     4
# College Communications Building     4        4     4     4     4     4
# Conference                          4        4     4     4     4     4
# Planetarium                         4        4     4     4     4     4
# General Entertainment               4        4     4     4     4     4
# Gift Shop                           4        4     4     4     4     4
# Other Event                         4        4     4     4     4     4
# College Quad                        4        4     4     4     4     4
# Alternative Healer                  4        4     4     4     4     4
# Historic Site                       4        4     4     4     4     4
# Event Space                         4        4     4     4     4     4
# Convention                          5        5     5     5     5     5
# Supermarket                         5        5     5     5     5     5
# High School                         5        5     5     5     5     5
# Coffee Shop                         6        6     6     6     6     6
# College Theater                     6        6     6     6     6     6
# Town Hall                           6        6     6     6     6     6
# Medical Center                      6        6     6     6     6     6
# Church                              7        7     7     7     7     7
# Photography Studio                  7        7     7     7     7     7
# Non-Profit                          7        7     7     7     7     7
# Print Shop                          7        7     7     7     7     7
# College Stadium                     7        7     7     7     7     7
# Research Station                    8        8     8     8     8     8
# Sorority House                      8        8     8     8     8     8
# Capitol Building                    8        8     8     8     8     8
# College Bookstore                   9        9     9     9     9     9
# College Engineering Building       10       10    10    10    10    10
# College Science Building           10       10    10    10    10    10
# Law School                         10       10    10    10    10    10
# School                             12       12    12    12    12    12
# Medical School                     12       12    12    12    12    12
# Building                           13       13    13    13    13    13
# IT Services                        13       13    13    13    13    13
# Fraternity House                   14       14    14    14    14    14
# Real Estate Office                 15       15    15    15    15    15
# Industrial Estate                  15       15    15    15    15    15
# Furniture / Home Store             17       17    17    17    17    17
# Community College                  17       17    17    17    17    17
# College Arts Building              18       18    18    18    18    18
# Post Office                        19       19    19    19    19    19
# College Lab                        21       21    21    21    21    21
# College Administrative Building    22       22    22    22    22    22
# Gas Station                        24       24    24    24    24    24
# College & University               25       25    25    25    25    25
# Construction & Landscaping         26       26    26    26    26    26
# Fire Station                       27       27    27    27    27    27
# Embassy / Consulate                27       27    27    27    27    27
# Science Museum                     29       29    29    29    29    29
# Miscellaneous Shop                 30       30    30    30    30    30
# College Cafeteria                  32       32    32    32    32    32
# Home Service                       32       32    32    32    32    32
# Student Center                     34       34    34    34    34    34
# Courthouse                         39       39    39    39    39    39
# College Auditorium                 39       39    39    39    39    39
# Trade School                       42       42    42    42    42    42
# Laboratory                         44       44    44    44    44    44
# College Residence Hall             46       46    46    46    46    46
# Monument / Landmark                47       47    47    47    47    47
# College Library                    52       52    52    52    52    52
# Adult Education Center             55       55    55    55    55    55
# College Gym                        56       56    56    56    56    56
# History Museum                     71       71    71    71    71    71
# General College & University       77       77    77    77    77    77
# College Academic Building          82       82    82    82    82    82
# University                         88       88    88    88    88    88
# Office                             92       92    92    92    92    92
# Police Station                     99       99    99    99    99    99
# Art Museum                        104      104   104   104   104   104
# College Classroom                 113      113   113   113   113   113
# Business Center                   183      183   183   183   183   183
# Recruiting Agency                 195      195   195   195   195   195
# City Hall                         208      208   208   208   208   208
# Lawyer                            245      245   245   245   245   245
# Government Building               247      247   247   247   247   247
# Advertising Agency                303      303   303   303   303   303
# Library                           331      331   331   331   331   331
# Design Studio                     351      351   351   351   351   351
# Factory                           448      448   448   448   448   448
# Insurance Office                  448      448   448   448   448   448
# Business Service                  470      470   470   470   470   470
# Financial or Legal Service        493      493   493   493   493   493
# Coworking Space                   603      603   603   603   603   603
# Tech Startup                      615      615   615   615   615   615
# Bank                             1198     1198  1198  1198  1198  1198
#
#                                  primary_category_id
# primary_category_name
# Accessories Store                                  1
# Memorial Site                                      1
# Medical Supply Store                               1
# Market                                             1
# Lighting Store                                     1
# Jewelry Store                                      1
# Hotel                                              1
# Health & Beauty Service                            1
# Gym                                                1
# Music Festival                                     1
# French Restaurant                                  1
# Festival                                           1
# Fair                                               1
# Exhibit                                            1
# Doner Restaurant                                   1
# Currency Exchange                                  1
# Cosmetics Shop                                     1
# Convenience Store                                  1
# Conference Room                                    1
# Waste Facility                                     1
# Music School                                       1
# Newsstand                                          1
# Outdoor Sculpture                                  1
# Veterinarian                                       1
# Trade Fair                                         1
# Thrift / Vintage Store                             1
# Theme Park                                         1
# Tennis Stadium                                     1
# Tailor Shop                                        1
# TV Station                                         1
# Street Fair                                        1
# States & Municipalities                            1
# Sporting Event                                     1
# Smoke Shop                                         1
# Shoe Store                                         1
# Sculpture Garden                                   1
# Radio Station                                      1
# Professional & Other Places                        1
# Performing Arts Venue                              1
# Pedestrian Plaza                                   1
# Parking                                            1
# Paper / Office Supplies Store                      1
# Comedy Club                                        1
# College Technology Building                        1
# Fountain                                           1
# Wine Bar                                           1
# Chocolate Shop                                     1
# Child Care Service                                 1
# Car Wash                                           1
# Camera Store                                       1
# Bookstore                                          1
# Bike Shop                                          1
# Basketball Stadium                                 1
# Auto Workshop                                      1
# Clothing Store                                     1
# Athletics & Sports                                 1
# Arts & Crafts Store                                1
# Art Studio                                         1
# Auto Dealership                                    1
# Transportation Service                             2
# Tourist Information Center                         2
# Castle                                             2
# College Math Building                              2
# Men's Store                                        2
# Middle School                                      2
# Event Service                                      2
# Mobile Phone Shop                                  2
# Museum                                             2
# Doctor's Office                                    2
# Café                                               2
# Dance Studio                                       2
# College Basketball Court                           2
# Other Repair Shop                                  2
# Parade                                             2
# Bridge                                             2
# Hospital                                           2
# Boutique                                           2
# Pet Service                                        2
# Big Box Store                                      2
# Concert Hall                                       2
# College Soccer Field                               2
# Automotive Shop                                    2
# College Track                                      2
# Cultural Center                                    2
# Convention Center                                  2
# Art Gallery                                        3
# College History Building                           3
# Electronics Store                                  4
# College Communications Building                    4
# Conference                                         4
# Planetarium                                        4
# General Entertainment                              4
# Gift Shop                                          4
# Other Event                                        4
# College Quad                                       4
# Alternative Healer                                 4
# Historic Site                                      4
# Event Space                                        4
# Convention                                         5
# Supermarket                                        5
# High School                                        5
# Coffee Shop                                        6
# College Theater                                    6
# Town Hall                                          6
# Medical Center                                     6
# Church                                             7
# Photography Studio                                 7
# Non-Profit                                         7
# Print Shop                                         7
# College Stadium                                    7
# Research Station                                   8
# Sorority House                                     8
# Capitol Building                                   8
# College Bookstore                                  9
# College Engineering Building                      10
# College Science Building                          10
# Law School                                        10
# School                                            12
# Medical School                                    12
# Building                                          13
# IT Services                                       13
# Fraternity House                                  14
# Real Estate Office                                15
# Industrial Estate                                 15
# Furniture / Home Store                            17
# Community College                                 17
# College Arts Building                             18
# Post Office                                       19
# College Lab                                       21
# College Administrative Building                   22
# Gas Station                                       24
# College & University                              25
# Construction & Landscaping                        26
# Fire Station                                      27
# Embassy / Consulate                               27
# Science Museum                                    29
# Miscellaneous Shop                                30
# College Cafeteria                                 32
# Home Service                                      32
# Student Center                                    34
# Courthouse                                        39
# College Auditorium                                39
# Trade School                                      42
# Laboratory                                        44
# College Residence Hall                            46
# Monument / Landmark                               47
# College Library                                   52
# Adult Education Center                            55
# College Gym                                       56
# History Museum                                    71
# General College & University                      77
# College Academic Building                         82
# University                                        88
# Office                                            92
# Police Station                                    99
# Art Museum                                       104
# College Classroom                                113
# Business Center                                  183
# Recruiting Agency                                195
# City Hall                                        208
# Lawyer                                           245
# Government Building                              247
# Advertising Agency                               303
# Library                                          331
# Design Studio                                    351
# Factory                                          448
# Insurance Office                                 448
# Business Service                                 470
# Financial or Legal Service                       493
# Coworking Space                                  603
# Tech Startup                                     615
# Bank                                            1198

# %%
# plot data
count_per_category['id'].tail(50).plot(kind='barh', figsize=(10, 20))

plt.xlabel('Number of places') # add to x-label to the plot
plt.ylabel('Place Category') # add y-label to the plot
plt.title('Ranking of Place Category in Paris Startup Ecosystem') # add title to the plot
plt.legend('') # add title to the plot

plt.show()

# %% [markdown]
# ## 3. Next Steps <a id='item3'></a>

# %% [markdown]
# In this notebook, we have collected data about Paris Startup Ecosystem. We then had a quick glance about the data through a map and an histogram. These data will be combined with others similar data from other Startup Ecosystem in the world then analyzed in a subsequent notebook. Then we will try to compare and identify similarity among these Startup Ecosystem through machine learning clustering techniques.

# %% [markdown]
# <hr>
#
# Copyright &copy; 2019 [Matt Sonnati](https://www.linkedin.com/in/matthieusonnati/). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license/).
