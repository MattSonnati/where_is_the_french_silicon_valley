# %% [markdown]
# # Exploratory Data Analysis: Silicon Valley Startup Ecosystem

# %% [markdown]
# ## Introduction
#
# In this notebook, we conduct an Exploratory Data Analysis (EDA) of data about the Startup Ecosystem of the Silicon Valley, collected from the [Foursquare Places API](https://developer.foursquare.com). The idea is to better understand what the startup ecosystem in San Fransisco-San Jose area is in order to compare it with others cities.
#
# [Foursquare Places API](https://developer.foursquare.com) being a geo dataset, the analysis will mainly revolve around geographical analysis and Data Visualization on maps. Our area of investigation will focus on the category and quantity of organizations and companies that are related to startup eosystem.
#
# Our EDA approach follows the **Data Science Methodology CRISP-DM**. For more info about this approach, check this [Wikipedia page](https://en.wikipedia.org/wiki/Cross-industry_standard_process_for_data_mining)

# %% [markdown]
# ## Table of contents
# 1. [Data Collection](#item1)
# 2. [Data Visualization](#item2)
# 3. [Next steps](#item3)

# %% [markdown]
# First let's download all the libraries required for this notebook.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

from bs4 import BeautifulSoup # library for web parsing 

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
import urllib.request
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library

from lxml.html import fromstring

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ## 1. Data Collection <a id='item1'></a>

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'xx' #  Foursquare ID
CLIENT_SECRET = 'xx' #  Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: xx
# CLIENT_SECRET:xx

# %% [markdown]
# #### Category selection

# %% [markdown]
# Foursquare has many categories. The full list can be accessed [here](https://developer.foursquare.com/docs/resources/categories). It goes from Restaurants to Stores and some of theses categories can widely impact any analysis just by their shear number of place. As a result, we decided to focus on selected categories that are more directely related to the life of startup, aka a Startup Ecosystem. We use the definition of a [Startup Ecosystem](https://en.wikipedia.org/wiki/Startup_ecosystem) according to Wikipedia.
# This list of category is definitely not exhaustive and could evolved based on the result of our analysis or any thoughtfull suggestions.

# %% [markdown]
# Obvisously the first category we selected was **Tech Startup** (4bf58dd8d48988d125941735) as this is the main focus of our analysis.
#
# Then we selected all the services that are required to the common operation of a startup:
# - **Coworking Space** (4bf58dd8d48988d174941735)
# - **Recruiting Agency** (52f2ab2ebcbc57f1066b8b57)
# - **Financial or Legal Service** (503287a291d4c4b30a586d65)
# - **Lawyer** (52f2ab2ebcbc57f1066b8b3f)
# - **Design Studio** (4bf58dd8d48988d1f4941735)
# - **Insurance Office** (58daa1558bbb0b01f18ec1f1)
# - **Business Service** (5453de49498eade8af355881)
# - **Business Center** (56aa371be4b08b9a8d573517)
# - **Advertising Agency** (52e81612bcbc57f1066b7a3d)
# - **Bank**	(4bf58dd8d48988d10a951735)
# - **Government Building**	(4bf58dd8d48988d126941735)
#
# We also selected the categories related to potential innovation partners of startup:
# - **College & University** (4d4b7105d754a06372d81259)
# - **Adult Education Center** (56aa371ce4b08b9a8d573570)
# - **Laboratory** (5744ccdfe4b0c0459246b4d6)
# - **Research Station** (58daa1558bbb0b01f18ec1b2)
#
# We also selected the categories related to potential industrial partners of startup:
# - **Industrial Estate** (56aa371be4b08b9a8d5734d7)
# - **Factory** (4eb1bea83b7b6f98df247e06)
#
# We also selected the categories related to potential cultural partners of startup:
# - **Library** (4bf58dd8d48988d12f941735)
# - **Science Museum** (4bf58dd8d48988d191941735)
# - **Art Museum** (4bf58dd8d48988d18f941735)
# - **History Museum** (4bf58dd8d48988d190941735)
# - **Planetarium** (4bf58dd8d48988d192941735)
#
#
#
# We then selected the category to various events that are required for startup to network and meet potential users or customers:
# - **Events** (4d4b7105d754a06373d81259)
# - **Trade Fair**	(5bae9231bedf3950379f89c3)
#
# The full list of categories was compiled in a csv file avaliable [here](https://raw.githubusercontent.com/MattSonnati/Data_Science_Coursera_Capstone/master/startup_ecosystem_category_list.csv)

# %%
startup_ecosystem_category_list = pd.read_csv('https://raw.githubusercontent.com/MattSonnati/where_is_the_french_silicon_valley/master/startup_ecosystem_category_list.csv').dropna()
startup_ecosystem_category_list
# Out:
#              4sq_category_name                    4sq_id color_code
# 0                 Tech Startup  4bf58dd8d48988d125941735    #32CD32
# 1              Coworking Space  4bf58dd8d48988d174941735    #ADFF2F
# 2             Insurance Office  58daa1558bbb0b01f18ec1f1    #FFD700
# 3            Recruiting Agency  52f2ab2ebcbc57f1066b8b57    #FFFFE0
# 4   Financial or Legal Service  503287a291d4c4b30a586d65    #FFE4B5
# 5                       Lawyer  52f2ab2ebcbc57f1066b8b3f    #FFFF00
# 6                   Laboratory  5744ccdfe4b0c0459246b4d6    #87CEFA
# 7         College & University  4d4b7105d754a06372d81259    #00BFFF
# 8       Adult Education Center  56aa371ce4b08b9a8d573570    #6495ED
# 9             Research Station  58daa1558bbb0b01f18ec1b2    #4169E1
# 10                     Library  4bf58dd8d48988d12f941735    #000080
# 11              Science Museum  4bf58dd8d48988d191941735    #EE82EE
# 12                  Art Museum  4bf58dd8d48988d18f941735    #8A2BE2
# 13              History Museum  4bf58dd8d48988d190941735    #9932CC
# 14                 Planetarium  4bf58dd8d48988d192941735    #800080
# 15                      Events  4d4b7105d754a06373d81259    #FF69B4
# 16             Business Center  56aa371be4b08b9a8d573517    #FF6347
# 17          Advertising Agency  52e81612bcbc57f1066b7a3d    #DC143C
# 18            Business Service  5453de49498eade8af355881    #FFA500
# 19               Design Studio  4bf58dd8d48988d1f4941735    #FFA07A
# 20                     Factory  4eb1bea83b7b6f98df247e06    #808080
# 21           Industrial Estate  56aa371be4b08b9a8d5734d7    #C0C0C0
# 22                        Bank  4bf58dd8d48988d10a951735    #008000
# 23                  Trade Fair  5bae9231bedf3950379f89c3    #AFEEEE
# 24         Government Building  4bf58dd8d48988d126941735    #F8F8FF

# %% [markdown]
# #### Area selection

# %% [markdown]
# In many instance, the geographical area referred to by poiting at a specific city is much wider than the administrative boundaries of said city.
#
# In this case, we are refering to several cities from San Fransisco, Palo alto, Mountain view up to San Jose which compose what's commonly called the "Bay area", SF or even more famously the Silicon Valley.
#
# We thus decided to include every cities within 50 km from Palo Alto.

# %% [markdown]
# We thus ask Foursquare API to find all the City (50aa9e094b90af0d42d5de0d) within 50000 meters from Palo Alto, CA

# %%
address_near = "Palo Alto, CA"
radius = 50000
category_id = "50aa9e094b90af0d42d5de0d"

# %%
# function that extracts the category name of the venue
def get_category_name(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venues.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
    # function that extracts the category of the venue
def get_category_id(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venues.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['id']
    
#create the GET request URL
LIMIT = 200

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&near={}&v={}&radius={}&limit={}&intent=browse&categoryId={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    address_near,  
    VERSION, 
    radius, 
    LIMIT,
    category_id)

# Send the GET request 
results = requests.get(url).json()

# Convert the JSON response into a dataframe
cities = results['response']['venues']
cities_list = json_normalize(cities) # flatten JSON

# filter columns
filtered_columns = ['name',
                    'id',
                    'location.postalCode',
                    'location.state',
                    'location.country',
                    'location.cc',
                    'location.lat', 
                    'location.lng',
                    'categories',]
cities_list =cities_list.loc[:, filtered_columns]

# filter the category for each row
cities_list['primary_category_name'] = cities_list.apply(get_category_name, axis=1)
cities_list['primary_category_id'] = cities_list.apply(get_category_id, axis=1)

# clean columns
cities_list.columns = [col.split(".")[-1] for col in cities_list.columns]

cities_list.head()
# Out:
#                     name                        id   postalCode       state  \
# 0  City of San Francisco  4c82f252d92ea09323185072        94103  California
# 1       City of San José  4c85e27147cc224b2fe6a49f        95112  California
# 2  City of Mountain View  4bef2c5bea570f4790058fd2        94041  California
# 3      City of Sunnyvale  4c572933d12a20a1471866bd  94085-94090  California
# 4      City of Palo Alto  4c3cc484b36ac9283d900486        94301  California
#
#          country  cc        lat         lng  \
# 0  United States  US  37.773836 -122.419624
# 1  United States  US  37.339895 -121.893587
# 2  United States  US  37.390294 -122.083383
# 3  United States  US  37.369748 -122.036777
# 4  United States  US  37.442060 -122.143005
#
#                                           categories primary_category_name  \
# 0  [{'id': '50aa9e094b90af0d42d5de0d', 'name': 'C...                  City
# 1  [{'id': '50aa9e094b90af0d42d5de0d', 'name': 'C...                  City
# 2  [{'id': '50aa9e094b90af0d42d5de0d', 'name': 'C...                  City
# 3  [{'id': '50aa9e094b90af0d42d5de0d', 'name': 'C...                  City
# 4  [{'id': '50aa9e094b90af0d42d5de0d', 'name': 'C...                  City
#
#         primary_category_id
# 0  50aa9e094b90af0d42d5de0d
# 1  50aa9e094b90af0d42d5de0d
# 2  50aa9e094b90af0d42d5de0d
# 3  50aa9e094b90af0d42d5de0d
# 4  50aa9e094b90af0d42d5de0d

# %%
cities_list.shape
# Out:
# (50, 11)

# %%
# Save dataframe as csv file to localhost
cities_list.to_csv(r'silicon_valley_cities_list.csv')

# Save dataframe as csv file to Watson studio (need token)
# project.save_data(data=cities_list.to_csv(index=False),file_name='silicon_valley_cities_list.csv',overwrite=True)

# %% [markdown]
# #### List of Startup Ecosystem places in Silicon Valley

# %% [markdown]
# For each city in the chosen area, we list all the places in our Category selection and within 5 km of said city.

# %%
def getCategoryVenues(name, latitude, longitude, radius, category_id):
    
    # create the API request URL
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}&intent=browse&categoryId={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    latitude, 
    longitude, 
    VERSION,
    radius, 
    LIMIT,
    category_id)

    # Send the GET request 
    results = requests.get(url).json()

    # Convert the JSON response into a dataframe
    category_venues = results['response']['venues']
    category_venues_list = json_normalize(category_venues) # flatten JSON

    # filter columns
    filtered_columns = ['name',
                            'id',
                            'location.postalCode',
                            'location.state',
                            'location.country',
                            'location.cc',
                            'location.lat', 
                            'location.lng',
                            'categories',]
    category_venues_list = category_venues_list.loc[:, filtered_columns]

    # filter the category for each row
    category_venues_list['primary_category_name'] = category_venues_list.apply(get_category_name, axis=1)
    category_venues_list['primary_category_id'] = category_venues_list.apply(get_category_id, axis=1)

    # clean columns
    category_venues_list.columns = [col.split(".")[-1] for col in category_venues_list.columns]

    return(category_venues_list)

# %%
radius = 5000
startup_ecosystem_place_list = pd.DataFrame(columns=['name','id','city','postalCode','state','country','cc','lat','lng','categoriesList','primary_category_name','primary_category_id'])

for category_name, category_id, color_code  in zip(startup_ecosystem_category_list['4sq_category_name'],
                                          startup_ecosystem_category_list['4sq_id'],
                                          startup_ecosystem_category_list['color_code']):
   
    for latitude, longitude, name  in zip(cities_list['lat'],
                                          cities_list['lng'],
                                          cities_list['name']):
        try:
            startup_ecosystem_place_list = pd.concat([startup_ecosystem_place_list, getCategoryVenues(name, latitude, longitude, radius, category_id)])
        except:
            pass

startup_ecosystem_place_list.drop_duplicates(subset=['id'], keep='first', inplace=True)
startup_ecosystem_place_list.head()
# Out:
# /Users/Matt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   if sys.path[0] == '':
# /Users/Matt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                                           categories categoriesList  cc city  \
# 0  [{'id': '4bf58dd8d48988d125941735', 'name': 'T...            NaN  US  NaN
# 1  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...            NaN  US  NaN
# 2  [{'id': '4bf58dd8d48988d125941735', 'name': 'T...            NaN  US  NaN
# 3  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...            NaN  US  NaN
# 4  [{'id': '4bf58dd8d48988d125941735', 'name': 'T...            NaN  US  NaN
#
#          country                        id        lat         lng  \
# 0  United States  51c7e853abd8cf897278ef48  37.771947 -122.405407
# 1  United States  505bc25be4b0c8fbe4f527af  37.775820 -122.418015
# 2  United States  57559629498e7c2350015efa  37.776339 -122.391740
# 3  United States  4ee0ecde29c2c6e332924109  37.776695 -122.416848
# 4  United States  580eb21938fa63491ce4a0c2  37.790112 -122.400330
#
#             name postalCode       primary_category_id primary_category_name  \
# 0      Airbnb HQ      94103  4bf58dd8d48988d125941735          Tech Startup
# 1        Uber HQ      94103  4bf58dd8d48988d124941735                Office
# 2        Lyft HQ      94107  4bf58dd8d48988d125941735          Tech Startup
# 3     Twitter HQ      94103  4bf58dd8d48988d124941735                Office
# 4  Uber HQ - 555      94105  4bf58dd8d48988d125941735          Tech Startup
#
#   state
# 0    CA
# 1    CA
# 2    CA
# 3    CA
# 4    CA

# %%
startup_ecosystem_place_list.shape
# Out:
# (11277, 13)

# %%
# Save dataframe as csv file to localhost
startup_ecosystem_place_list.to_csv(r'silicon_valley_startup_ecosystem_place_list.csv')

# Save dataframe as csv file to Watson studio (need token)
# project.save_data(data=startup_ecosystem_place_list.to_csv(index=False),file_name='silicon_valley_startup_ecosystem_place_list.csv',overwrite=True)

# %% [markdown]
# ## 2. Data Visualization <a id='item2'></a>

# %% [markdown]
# First, let define a function to creat map from a list of Place based on their latitude and longitude coordinate.

# %%
def getMap(centerPlace, venues_list):

    # create a user agent
    geolocator = Nominatim(user_agent="fr_explorer")

    address = centerPlace
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude

    # create map using latitude and longitude values
    map_venues = folium.Map(location=[latitude, longitude], zoom_start=11)

    # add markers to map
    for lat, lng, name, postalCode  in zip(venues_list['lat'], 
                                                          venues_list['lng'], 
                                                          venues_list['name'], 
                                                          venues_list['postalCode']):
        label = '{} {}'.format(name, postalCode)
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            popup=label,
            color='blue',
            fill=True,
            fill_color='#3186cc',
            fill_opacity=0.7,
            parse_html=False).add_to(map_venues)  

    return(map_venues)

# %% [markdown]
# Map of cities within X0 km from Palo Alto

# %%
 getMap('Palo Alto, CA', cities_list)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### To better understand Paris Startup Ecosystem, we can take a look at the number of place in each categories.

# %% [markdown]
# In order to better visualize these data, we can plot them as a horizontal bar plot.

# %%
count_per_category = startup_ecosystem_place_list.groupby('primary_category_name').count()
count_per_category.drop(['categories','categoriesList','state','postalCode','city'], axis=1, inplace=True)
count_per_category.sort_values(['id'], ascending=True, axis=0, inplace=True)
count_per_category
# Out:
#                                             cc  country    id   lat   lng  \
# primary_category_name
# Zoo                                          1        1     1     1     1
# Military Base                                1        1     1     1     1
# College Tennis Court                         1        1     1     1     1
# Moving Target                                1        1     1     1     1
# Music Venue                                  1        1     1     1     1
# Nature Preserve                              1        1     1     1     1
# Neighborhood                                 1        1     1     1     1
# Nursery School                               1        1     1     1     1
# Other Great Outdoors                         1        1     1     1     1
# Men's Store                                  1        1     1     1     1
# Outdoor Sculpture                            1        1     1     1     1
# Pawn Shop                                    1        1     1     1     1
# Performing Arts Venue                        1        1     1     1     1
# College Cricket Pitch                        1        1     1     1     1
# Physical Therapist                           1        1     1     1     1
# Funeral Home                                 1        1     1     1     1
# Pool                                         1        1     1     1     1
# Preschool                                    1        1     1     1     1
# Public Art                                   1        1     1     1     1
# Outdoor Supply Store                         1        1     1     1     1
# Radio Station                                1        1     1     1     1
# Memorial Site                                1        1     1     1     1
# Conference Room                              1        1     1     1     1
# General Entertainment                        1        1     1     1     1
# Farmers Market                               1        1     1     1     1
# Gift Shop                                    1        1     1     1     1
# Women's Store                                1        1     1     1     1
# Event Service                                1        1     1     1     1
# Hobby Shop                                   1        1     1     1     1
# Hockey Arena                                 1        1     1     1     1
# Housing Development                          1        1     1     1     1
# Concert Hall                                 1        1     1     1     1
# Indie Movie Theater                          1        1     1     1     1
# Indoor Play Area                             1        1     1     1     1
# Intersection                                 1        1     1     1     1
# Language School                              1        1     1     1     1
# Lighting Store                               1        1     1     1     1
# Corporate Amenity                            1        1     1     1     1
# Cooking School                               1        1     1     1     1
# Convention Center                            1        1     1     1     1
# Massage Studio                               1        1     1     1     1
# Department Store                             1        1     1     1     1
# Recording Studio                             1        1     1     1     1
# Plane                                        1        1     1     1     1
# Rehab Center                                 1        1     1     1     1
# Brewery                                      1        1     1     1     1
# Basketball Stadium                           1        1     1     1     1
# Basketball Court                             1        1     1     1     1
# Baseball Stadium                             1        1     1     1     1
# Supermarket                                  1        1     1     1     1
# TV Station                                   1        1     1     1     1
# Auto Dealership                              1        1     1     1     1
# Auditorium                                   1        1     1     1     1
# Bridge                                       1        1     1     1     1
# Arts & Entertainment                         1        1     1     1     1
# Train Station                                1        1     1     1     1
# Arcade                                       1        1     1     1     1
# Aquarium                                     1        1     1     1     1
# Amphitheater                                 1        1     1     1     1
# Airport Lounge                               1        1     1     1     1
# Veterinarian                                 1        1     1     1     1
# Waste Facility                               1        1     1     1     1
# Accessories Store                            1        1     1     1     1
# Train                                        1        1     1     1     1
# Burger Joint                                 1        1     1     1     1
# Board Shop                                   1        1     1     1     1
# Flower Shop                                  1        1     1     1     1
# Spiritual Center                             1        1     1     1     1
# Cheese Shop                                  1        1     1     1     1
# Roof Deck                                    1        1     1     1     1
# Shoe Store                                   1        1     1     1     1
# Cemetery                                     1        1     1     1     1
# Carpet Store                                 1        1     1     1     1
# Shopping Plaza                               1        1     1     1     1
# Chiropractor                                 1        1     1     1     1
# Soccer Field                                 1        1     1     1     1
# Speakeasy                                    1        1     1     1     1
# Club House                                   1        1     1     1     1
# Post Office                                  2        2     2     2     2
# Transportation Service                       2        2     2     2     2
# Rental Service                               2        2     2     2     2
# Playground                                   2        2     2     2     2
# Salon / Barbershop                           2        2     2     2     2
# General Travel                               2        2     2     2     2
# Scenic Lookout                               2        2     2     2     2
# Hotel                                        2        2     2     2     2
# Golf Course                                  2        2     2     2     2
# Gym                                          2        2     2     2     2
# Movie Theater                                2        2     2     2     2
# Tourist Information Center                   2        2     2     2     2
# Sculpture Garden                             2        2     2     2     2
# Park                                         2        2     2     2     2
# Locksmith                                    2        2     2     2     2
# Parade                                       2        2     2     2     2
# Marijuana Dispensary                         2        2     2     2     2
# Medical Supply Store                         2        2     2     2     2
# Recycling Facility                           2        2     2     2     2
# Storage Facility                             2        2     2     2     2
# Motel                                        2        2     2     2     2
# Stoop Sale                                   2        2     2     2     2
# Photography Lab                              2        2     2     2     2
# Jewelry Store                                2        2     2     2     2
# Harbor / Marina                              2        2     2     2     2
# Clothing Store                               2        2     2     2     2
# Automotive Shop                              2        2     2     2     2
# Dance Studio                                 2        2     2     2     2
# Cultural Center                              2        2     2     2     2
# Farm                                         2        2     2     2     2
# Boat or Ferry                                2        2     2     2     2
# Doctor's Office                              3        3     3     3     3
# Parking                                      3        3     3     3     3
# Sporting Event                               3        3     3     3     3
# Law School                                   3        3     3     3     3
# College Stadium                              3        3     3     3     3
# Art Studio                                   3        3     3     3     3
# Check Cashing Service                        3        3     3     3     3
# Field                                        3        3     3     3     3
# Plaza                                        3        3     3     3     3
# Middle School                                3        3     3     3     3
# Community Center                             3        3     3     3     3
# College Math Building                        3        3     3     3     3
# Convention                                   4        4     4     4     4
# Medical Lab                                  4        4     4     4     4
# Event Space                                  4        4     4     4     4
# Town Hall                                    4        4     4     4     4
# Gym / Fitness Center                         4        4     4     4     4
# Photography Studio                           4        4     4     4     4
# Child Care Service                           4        4     4     4     4
# College History Building                     4        4     4     4     4
# Church                                       5        5     5     5     5
# College Soccer Field                         5        5     5     5     5
# High School                                  5        5     5     5     5
# College & University                         5        5     5     5     5
# Residential Building (Apartment / Condo)     5        5     5     5     5
# Exhibit                                      5        5     5     5     5
# Real Estate Office                           5        5     5     5     5
# Café                                         5        5     5     5     5
# School                                       5        5     5     5     5
# Professional & Other Places                  5        5     5     5     5
# College Baseball Diamond                     5        5     5     5     5
# Urgent Care Center                           5        5     5     5     5
# Dentist's Office                             5        5     5     5     5
# Electronics Store                            5        5     5     5     5
# ATM                                          6        6     6     6     6
# Medical Center                               6        6     6     6     6
# Arts & Crafts Store                          6        6     6     6     6
# College Basketball Court                     7        7     7     7     7
# Art Gallery                                  7        7     7     7     7
# Historic Site                                7        7     7     7     7
# Embassy / Consulate                          7        7     7     7     7
# Elementary School                            7        7     7     7     7
# Christmas Market                             7        7     7     7     7
# College Communications Building              8        8     8     8     8
# College Track                                8        8     8     8     8
# Hardware Store                               8        8     8     8     8
# Capitol Building                             8        8     8     8     8
# Paper / Office Supplies Store                8        8     8     8     8
# Music Festival                               8        8     8     8     8
# Street Fair                                  8        8     8     8     8
# Non-Profit                                   8        8     8     8     8
# Research Station                             9        9     9     9     9
# Miscellaneous Shop                          10       10    10    10    10
# Sorority House                              11       11    11    11    11
# College Theater                             11       11    11    11    11
# Conference                                  12       12    12    12    12
# Hospital                                    12       12    12    12    12
# Museum                                      12       12    12    12    12
# College Football Field                      13       13    13    13    13
# Planetarium                                 14       14    14    14    14
# Industrial Estate                           14       14    14    14    14
# Furniture / Home Store                      15       15    15    15    15
# College Rec Center                          16       16    16    16    16
# Mobile Phone Shop                           16       16    16    16    16
# IT Services                                 17       17    17    17    17
# College Engineering Building                18       18    18    18    18
# Home Service                                18       18    18    18    18
# College Bookstore                           18       18    18    18    18
# Travel Agency                               18       18    18    18    18
# College Technology Building                 18       18    19    19    19
# College Auditorium                          20       20    20    20    20
# Construction & Landscaping                  21       21    21    21    21
# College Arts Building                       22       22    22    22    22
# Medical School                              23       23    23    23    23
# Fraternity House                            24       24    24    24    24
# College Lab                                 24       24    24    24    24
# Other Event                                 24       24    24    24    24
# Festival                                    28       28    28    28    28
# Credit Union                                28       28    28    28    28
# Community College                           30       30    30    30    30
# College Science Building                    30       30    30    30    30
# College Cafeteria                           31       31    31    31    31
# College Quad                                32       32    32    32    32
# College Library                             35       35    35    35    35
# College Residence Hall                      39       39    39    39    39
# College Gym                                 40       40    40    40    40
# Adult Education Center                      41       41    41    41    41
# Courthouse                                  41       41    41    41    41
# Art Museum                                  42       42    42    42    42
# Building                                    48       48    48    48    48
# Print Shop                                  51       51    51    51    51
# Trade School                                53       53    53    53    53
# University                                  55       55    55    55    55
# Monument / Landmark                         64       64    64    64    64
# Science Museum                              65       65    65    65    65
# College Administrative Building             77       77    77    77    77
# City Hall                                   82       82    82    82    82
# Student Center                              85       85    85    85    85
# Police Station                              89       89    89    89    89
# Recruiting Agency                           91       91    91    91    91
# Shipping Store                              93       93    93    93    93
# History Museum                              99       99    99    99    99
# General College & University               102      102   102   102   102
# College Academic Building                  106      106   106   106   106
# College Classroom                          116      116   116   116   116
# Laboratory                                 124      124   124   124   124
# Fire Station                               168      168   168   168   168
# Advertising Agency                         201      201   201   201   201
# Library                                    287      287   287   287   287
# Office                                     339      339   339   339   339
# Government Building                        348      348   348   348   348
# Business Center                            395      395   395   395   395
# Design Studio                              448      448   448   448   448
# Insurance Office                           503      503   503   503   503
# Factory                                    595      595   595   595   595
# Bank                                       822      822   822   822   822
# Coworking Space                            851      851   851   851   851
# Lawyer                                     854      854   854   854   854
# Business Service                           890      890   890   890   890
# Tech Startup                               924      924   924   924   924
# Financial or Legal Service                1002     1002  1002  1002  1002
#
#                                           name  primary_category_id
# primary_category_name
# Zoo                                          1                    1
# Military Base                                1                    1
# College Tennis Court                         1                    1
# Moving Target                                1                    1
# Music Venue                                  1                    1
# Nature Preserve                              1                    1
# Neighborhood                                 1                    1
# Nursery School                               1                    1
# Other Great Outdoors                         1                    1
# Men's Store                                  1                    1
# Outdoor Sculpture                            1                    1
# Pawn Shop                                    1                    1
# Performing Arts Venue                        1                    1
# College Cricket Pitch                        1                    1
# Physical Therapist                           1                    1
# Funeral Home                                 1                    1
# Pool                                         1                    1
# Preschool                                    1                    1
# Public Art                                   1                    1
# Outdoor Supply Store                         1                    1
# Radio Station                                1                    1
# Memorial Site                                1                    1
# Conference Room                              1                    1
# General Entertainment                        1                    1
# Farmers Market                               1                    1
# Gift Shop                                    1                    1
# Women's Store                                1                    1
# Event Service                                1                    1
# Hobby Shop                                   1                    1
# Hockey Arena                                 1                    1
# Housing Development                          1                    1
# Concert Hall                                 1                    1
# Indie Movie Theater                          1                    1
# Indoor Play Area                             1                    1
# Intersection                                 1                    1
# Language School                              1                    1
# Lighting Store                               1                    1
# Corporate Amenity                            1                    1
# Cooking School                               1                    1
# Convention Center                            1                    1
# Massage Studio                               1                    1
# Department Store                             1                    1
# Recording Studio                             1                    1
# Plane                                        1                    1
# Rehab Center                                 1                    1
# Brewery                                      1                    1
# Basketball Stadium                           1                    1
# Basketball Court                             1                    1
# Baseball Stadium                             1                    1
# Supermarket                                  1                    1
# TV Station                                   1                    1
# Auto Dealership                              1                    1
# Auditorium                                   1                    1
# Bridge                                       1                    1
# Arts & Entertainment                         1                    1
# Train Station                                1                    1
# Arcade                                       1                    1
# Aquarium                                     1                    1
# Amphitheater                                 1                    1
# Airport Lounge                               1                    1
# Veterinarian                                 1                    1
# Waste Facility                               1                    1
# Accessories Store                            1                    1
# Train                                        1                    1
# Burger Joint                                 1                    1
# Board Shop                                   1                    1
# Flower Shop                                  1                    1
# Spiritual Center                             1                    1
# Cheese Shop                                  1                    1
# Roof Deck                                    1                    1
# Shoe Store                                   1                    1
# Cemetery                                     1                    1
# Carpet Store                                 1                    1
# Shopping Plaza                               1                    1
# Chiropractor                                 1                    1
# Soccer Field                                 1                    1
# Speakeasy                                    1                    1
# Club House                                   1                    1
# Post Office                                  2                    2
# Transportation Service                       2                    2
# Rental Service                               2                    2
# Playground                                   2                    2
# Salon / Barbershop                           2                    2
# General Travel                               2                    2
# Scenic Lookout                               2                    2
# Hotel                                        2                    2
# Golf Course                                  2                    2
# Gym                                          2                    2
# Movie Theater                                2                    2
# Tourist Information Center                   2                    2
# Sculpture Garden                             2                    2
# Park                                         2                    2
# Locksmith                                    2                    2
# Parade                                       2                    2
# Marijuana Dispensary                         2                    2
# Medical Supply Store                         2                    2
# Recycling Facility                           2                    2
# Storage Facility                             2                    2
# Motel                                        2                    2
# Stoop Sale                                   2                    2
# Photography Lab                              2                    2
# Jewelry Store                                2                    2
# Harbor / Marina                              2                    2
# Clothing Store                               2                    2
# Automotive Shop                              2                    2
# Dance Studio                                 2                    2
# Cultural Center                              2                    2
# Farm                                         2                    2
# Boat or Ferry                                2                    2
# Doctor's Office                              3                    3
# Parking                                      3                    3
# Sporting Event                               3                    3
# Law School                                   3                    3
# College Stadium                              3                    3
# Art Studio                                   3                    3
# Check Cashing Service                        3                    3
# Field                                        3                    3
# Plaza                                        3                    3
# Middle School                                3                    3
# Community Center                             3                    3
# College Math Building                        3                    3
# Convention                                   4                    4
# Medical Lab                                  4                    4
# Event Space                                  4                    4
# Town Hall                                    4                    4
# Gym / Fitness Center                         4                    4
# Photography Studio                           4                    4
# Child Care Service                           4                    4
# College History Building                     4                    4
# Church                                       5                    5
# College Soccer Field                         5                    5
# High School                                  5                    5
# College & University                         5                    5
# Residential Building (Apartment / Condo)     5                    5
# Exhibit                                      5                    5
# Real Estate Office                           5                    5
# Café                                         5                    5
# School                                       5                    5
# Professional & Other Places                  5                    5
# College Baseball Diamond                     5                    5
# Urgent Care Center                           5                    5
# Dentist's Office                             5                    5
# Electronics Store                            5                    5
# ATM                                          6                    6
# Medical Center                               6                    6
# Arts & Crafts Store                          6                    6
# College Basketball Court                     7                    7
# Art Gallery                                  7                    7
# Historic Site                                7                    7
# Embassy / Consulate                          7                    7
# Elementary School                            7                    7
# Christmas Market                             7                    7
# College Communications Building              8                    8
# College Track                                8                    8
# Hardware Store                               8                    8
# Capitol Building                             8                    8
# Paper / Office Supplies Store                8                    8
# Music Festival                               8                    8
# Street Fair                                  8                    8
# Non-Profit                                   8                    8
# Research Station                             9                    9
# Miscellaneous Shop                          10                   10
# Sorority House                              11                   11
# College Theater                             11                   11
# Conference                                  12                   12
# Hospital                                    12                   12
# Museum                                      12                   12
# College Football Field                      13                   13
# Planetarium                                 14                   14
# Industrial Estate                           14                   14
# Furniture / Home Store                      15                   15
# College Rec Center                          16                   16
# Mobile Phone Shop                           16                   16
# IT Services                                 17                   17
# College Engineering Building                18                   18
# Home Service                                18                   18
# College Bookstore                           18                   18
# Travel Agency                               18                   18
# College Technology Building                 19                   19
# College Auditorium                          20                   20
# Construction & Landscaping                  21                   21
# College Arts Building                       22                   22
# Medical School                              23                   23
# Fraternity House                            24                   24
# College Lab                                 24                   24
# Other Event                                 24                   24
# Festival                                    28                   28
# Credit Union                                28                   28
# Community College                           30                   30
# College Science Building                    30                   30
# College Cafeteria                           31                   31
# College Quad                                32                   32
# College Library                             35                   35
# College Residence Hall                      39                   39
# College Gym                                 40                   40
# Adult Education Center                      41                   41
# Courthouse                                  41                   41
# Art Museum                                  42                   42
# Building                                    48                   48
# Print Shop                                  51                   51
# Trade School                                53                   53
# University                                  55                   55
# Monument / Landmark                         64                   64
# Science Museum                              65                   65
# College Administrative Building             77                   77
# City Hall                                   82                   82
# Student Center                              85                   85
# Police Station                              89                   89
# Recruiting Agency                           91                   91
# Shipping Store                              93                   93
# History Museum                              99                   99
# General College & University               102                  102
# College Academic Building                  106                  106
# College Classroom                          116                  116
# Laboratory                                 124                  124
# Fire Station                               168                  168
# Advertising Agency                         201                  201
# Library                                    287                  287
# Office                                     339                  339
# Government Building                        348                  348
# Business Center                            395                  395
# Design Studio                              448                  448
# Insurance Office                           503                  503
# Factory                                    595                  595
# Bank                                       822                  822
# Coworking Space                            851                  851
# Lawyer                                     854                  854
# Business Service                           890                  890
# Tech Startup                               924                  924
# Financial or Legal Service                1002                 1002

# %%
# plot data
count_per_category['id'].tail(50).plot(kind='barh', figsize=(10, 20))

plt.xlabel('Number of places') # add to x-label to the plot
plt.ylabel('Place Category') # add y-label to the plot
plt.title('Ranking of Place Category in Silicon Valley Startup Ecosystem') # add title to the plot
plt.legend('') # add title to the plot

plt.show()

# %% [markdown]
# ## 3. Next Steps <a id='item3'></a>

# %% [markdown]
# In this notebook, we have collected data about Paris Startup Ecosystem. We then had a quick glance about the data through a map and an histogram. These data will be combined with others similar data from other Startup Ecosystem in the world then analyzed in a subsequent notebook. Then we will try to compare and identify similarity among these Startup Ecosystem through machine learning clustering techniques.

# %% [markdown]
# <hr>
#
# Copyright &copy; 2019 [Matt Sonnati](https://www.linkedin.com/in/matthieusonnati/). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license/).
